# %% [markdown]
# <a href="https://colab.research.google.com/github/abirzishan32/ML-Practice/blob/main/Support_Vector_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR

# %% [markdown]
# #Sample Data

# %%
feature = np.array([[1], [2], [3], [4], [5]])
target = np.array([1.5, 1.8, 3.2, 4.5, 5.1])

# %% [markdown]
# # Creating and training the SVR model with RBF kernel

# %%
regressor = SVR(kernel='rbf', C=100, epsilon=0.1, gamma=0.1)
regressor.fit(feature, target)
# Out:
# SVR(C=100, gamma=0.1)

# %% [markdown]
# # Making predictions

# %%
target_pred = regressor.predict(X)

# %% [markdown]
# # Plotting the results

# %%
plt.scatter(feature, target, color='red', label='Original data')
plt.plot(feature, target_pred, color='blue', label='SVR model')
plt.title('Support Vector Regression with RBF Kernel')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
